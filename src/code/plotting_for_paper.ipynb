# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')

# %%
import pandas as pd
data = pd.read_csv('../results/results_summary.csv')
current_13 = pd.read_csv('../results/results_summary_demand=13_posts=original_allocation=current_year=2019.csv')

# %%
data
# Out:
#       Demand Level  Scenario  Resource Level  Trial  Percent Abandoned  \
# 0               13    single              60      0           0.006507
# 1               13    single              60      1           0.006695
# 2               13    single              60      2           0.007168
# 3               13    single              60      3           0.006721
# 4               13    single              60      4           0.006554
# ...            ...       ...             ...    ...                ...
# 1315            45  multiple             124      0           0.080276
# 1316            45  multiple             124      1           0.078265
# 1317            45  multiple             124      2           0.083241
# 1318            45  multiple             124      3           0.082321
# 1319            45  multiple             124      4           0.076198
#
#       Ambulance Utilisation  RRV Utilisation  Mean Response Time
# ...

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='single')
    ].groupby('Resource Level')['Ambulance Utilisation'].mean() * 100
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(0, 100)
ax.set_ylabel('Ambulance Utilisation (%)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Single Vehicle', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/single_AmbulanceUtilisation.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='multiple')
    ].groupby('Resource Level')['Ambulance Utilisation'].mean() * 100
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(0, 100)
ax.set_ylabel('Ambulance Utilisation (%)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Multiple Vehicles', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/multiple_AmbulanceUtilisation.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='multiple')
    ].groupby('Resource Level')['RRV Utilisation'].mean() * 100
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(0, 100)
ax.set_ylabel('RRV Utilisation (%)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Multiple Vehicles', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/multiple_RRVUtilisation.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='single')
    ].groupby('Resource Level')['Mean Response Time'].mean() * 1440
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(16, 30)
ax.set_ylabel('Mean Response Time (mins)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Single Vehicle', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/single_MeanResponseTime.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='multiple')
    ].groupby('Resource Level')['Mean Response Time'].mean() * 1440
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(16, 30)
ax.set_ylabel('Mean Response Time (mins)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Multiple Vehicles', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/multiple_MeanResponseTime.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='single')
    ].groupby('Resource Level')['Percent Abandoned'].mean() * 100
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(0, 40)
ax.set_ylabel('Percent Abandoned (%)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Single Vehicle', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/single_PercentAbandoned.pdf')

# %%
colours = ['forestgreen', 'gold', 'darkorange', 'red']
fig, ax = plt.subplots(1)
for demand_level, colour in zip([13, 19, 34, 45], colours):
    ys = data[
        (data['Demand Level']==demand_level) & (data['Scenario']=='multiple')
    ].groupby('Resource Level')['Percent Abandoned'].mean() * 100
    ax.plot(range(60, 125, 2), ys, color=colour, label=f"D{demand_level}")
ax.set_ylim(0, 40)
ax.set_ylabel('Percent Abandoned (%)', fontsize=16)
ax.set_xlabel('Resource Level', fontsize=16)
ax.set_xlim(60, 124)
ax.set_xticks(range(60, 125, 4))
ax.tick_params(axis='y', which='major', labelsize=14)
ax.set_title('Scenario: Multiple Vehicles', fontsize=16, y=1.2)
ax.legend(ncol=4, frameon=True, fontsize=13, title="Demand Scenario", bbox_to_anchor=(0.98, 1.23))
plt.subplots_adjust(top=0.75)
fig.savefig('../../../upgraded-octo-barnacle/tex/img/plots/multiple_PercentAbandoned.pdf')

# %%
current_13.mean() * 100
# Out:
# Trial                    200.000000
# Percent Abandoned          0.000000
# Ambulance Utilisation     30.994251
# RRV Utilisation           22.465235
# Mean Response Time         1.228157
# dtype: float64

# %%
data[(data['Scenario']=='single') & (data['Demand Level']==45)].groupby('Resource Level')['Percent Abandoned'].mean() * 100
# Out:
# Resource Level
# 60     21.656825
# 62     20.189827
# 64     18.752545
# 66     17.344806
# 68     15.881260
# 70     14.634981
# 72     14.659139
# 74     12.137585
# 76     10.991602
# 78      9.976715
# 80      8.903930
# 82      7.968191
# 84      7.104239
# 86      6.273761
# 88      5.418212
# 90      5.345366
# 92      4.540010
# 94      3.858365
# 96      3.332403
# 98      2.790568
# 100     2.333633
# 102     1.902884
# 104     1.500940
# 106     1.223396
# 108     1.006858
# 110     0.816229
# 112     0.700922
# 114     0.584945
# 116     0.525364
# 118     0.450730
# 120     0.556197
# 122     0.509199
# 124     0.487827
# Name: Percent Abandoned, dtype: float64

# %%
print(
    np.genfromtxt('../data/posts/original/allocations/demand_19_multiple_120.csv').sum(),
    np.genfromtxt('../data/posts/original/allocations_secondary/demand_19_multiple_120.csv').sum()
)
# Out:
# 70.0 150.0

# %%
111/3
# Out:
# 37.0
